# %%
import matplotlib.pyplot as plt
import numpy as np
import spectral.io.envi as envi
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from sklearn import preprocessing
from scipy.signal import savgol_filter
from scipy.ndimage import gaussian_filter
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from pathlib import Path
from PIL import Image
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, InputLayer, BatchNormalization, Dropout
import h5py
from skimage.transform import resize
from skimage.transform import rotate
from skimage.transform import  AffineTransform,warp
from keras.preprocessing.image import ImageDataGenerator
import os, glob
import shutil

# %%
source_tumor = '/../../../data/mudahmad/Tumor Files/'
source_nontumor= '/../../../data/mudahmad/Non Tumor Files/'
destination_images= '/../../../data/mudahmad/256_size_images/images/'
destination_masks= '/../../../data/mudahmad/256_size_images/masks/'

# %% [markdown]
# Add All Spec Images from Tumor and Non Tumor Files to Images.

# %%
folders = os.listdir(source_tumor)
i=0
j=0
for filename in folders:
    subdir= os.path.join(source_tumor, filename)
    print(subdir)
    # checking if it is a file
    if not os.path.isfile(subdir):
        try:
            for file in glob.glob(subdir+"/spec_256*"):
                print(i)
#                 splitfile=file.split('/')[-1]
#                 fil_specfilename=splitfile.split('.')
#                 specfile=fil_specfilename[0]+"_"+str(i)
#                 print("s",specfile)
                
                #shutil.move(file, destination_images +specfile )
                i+=1
        except:
            print("File not present")
        try:
            for filemask in glob.glob(subdir+"/mask_256*"):
                splitfilemask=filemask.split('/')[-1]
                fil_maskfilename=splitfilemask.split('.')
                maskfile=fil_maskfilename[0]+"_"+str(j)
                print(maskfile)
                j+=1
        except:
            print("file not present")
# Out:
# /../../../data/mudahmad/Tumor Files/README.txt
# /../../../data/mudahmad/Tumor Files/008-01
# mask_256_0
# mask_256_rot_30_1
# mask_256_rot_45_2
# mask_256_rot_60_3
# mask_256_rot_75_4
# mask_256_rot_90_5
# /../../../data/mudahmad/Tumor Files/008-02
# mask_256_6
# mask_256_rot_30_7
# mask_256_rot_45_8
# mask_256_rot_60_9
# mask_256_rot_75_10
# mask_256_rot_90_11
# /../../../data/mudahmad/Tumor Files/012-01
# mask_256_12
# mask_256_rot_30_13
# mask_256_rot_45_14
# mask_256_rot_60_15
# mask_256_rot_75_16
# mask_256_rot_90_17
# /../../../data/mudahmad/Tumor Files/012-02
# mask_256_18
# mask_256_rot_30_19
# mask_256_rot_45_20
# mask_256_rot_60_21
# mask_256_rot_75_22
# mask_256_rot_90_23
# /../../../data/mudahmad/Tumor Files/015-01
# mask_256_24
# mask_256_rot_30_25
# mask_256_rot_45_26
# mask_256_rot_60_27
# mask_256_rot_75_28
# mask_256_rot_90_29
# /../../../data/mudahmad/Tumor Files/020-01
# mask_256_30
# mask_256_rot_30_31
# mask_256_rot_45_32
# mask_256_rot_60_33
# ...
